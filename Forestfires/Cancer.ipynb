# %%
import pandas as pd

from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import ConfusionMatrixDisplay, precision_score, recall_score, f1_score, confusion_matrix

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Reading the dataset

# %%
# Reading CSV
cancer_df = pd.read_csv('./data/cancer.csv', sep = ',')

# %%
# Deleting unused column
del cancer_df['Unnamed: 32']

# %%
cancer_df.shape
# Out:
# (569, 32)

# %%
cancer_df.dtypes
# Out:
# id                           int64
# diagnosis                   object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# compactness_worst          float64
# concavity_worst            float64
# concave points_worst       float64
# symmetry_worst             float64
# fractal_dimension_worst    float64
# dtype: object

# %%
cancer_df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %% [markdown]
# ### Splitting train and test datasets

# %%
# Selecting features to train the model
features = cancer_df.columns.tolist()[2:]

# %%
# Creating feature matrix
X = cancer_df[features]

# %%
# Creating target
Y = cancer_df['diagnosis'].replace({'B': 0, 'M': 1})

# %%
pd.Series(Y).value_counts(normalize = True)
# Out:
# 0    0.627417
# 1    0.372583
# Name: diagnosis, dtype: float64

# %%
# Splitting feature matrix for training (70%) and test (30%)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, stratify = Y)

# %%
pd.Series(Y_train).value_counts(normalize = True)
# Out:
# 0    0.628141
# 1    0.371859
# Name: diagnosis, dtype: float64

# %%
pd.Series(Y_test).value_counts(normalize = True)
# Out:
# 0    0.625731
# 1    0.374269
# Name: diagnosis, dtype: float64

# %% [markdown]
# ### Training the model

# %%
# Initializing the model
model = DecisionTreeClassifier()

# %%
# Training the model using training dataset
model.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Plotting the tree model
plt.figure(figsize = (30, 20))
plot_tree(model, feature_names = features, class_names = ['B', 'M'])
# Out:
# [Text(1124.71875, 1019.25, 'area_worst <= 868.2\ngini = 0.467\nsamples = 398\nvalue = [250, 148]\nclass = B'),
#  Text(784.6875, 883.35, 'concave points_worst <= 0.176\ngini = 0.151\nsamples = 268\nvalue = [246, 22]\nclass = B'),
#  Text(680.0625, 747.45, 'concave points_worst <= 0.132\ngini = 0.082\nsamples = 257\nvalue = [246, 11]\nclass = B'),
#  Text(313.875, 611.55, 'fractal_dimension_worst <= 0.057\ngini = 0.025\nsamples = 235\nvalue = [232, 3]\nclass = B'),
#  Text(209.25, 475.65, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = M'),
#  Text(418.5, 475.65, 'smoothness_se <= 0.003\ngini = 0.017\nsamples = 234\nvalue = [232, 2]\nclass = B'),
#  Text(209.25, 339.75, 'smoothness_se <= 0.003\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = B'),
#  Text(104.625, 203.85000000000002, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = B'),
#  Text(313.875, 203.85000000000002, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = M'),
#  Text(627.75, 339.75, 'texture_worst <= 33.35\ngini = 0.009\nsamples = 230\nvalue = [229, 1]\nclass = B'),
#  Text(523.125, 203.85000000000002, 'gini = 0.0\nsamples = 218\nvalue = [218, 0]\nclass = B'),
#  Text(732.375, 203.85000000000002, 'texture_mean <= 23.2\ngini = 0.153\nsamples = 12\nvalue = [11, 1]\nclass = B'),
#  Text(627.75, 67.95000000000005, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = M'),
#  Text(837.0, 67.95000000000005, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]\nclass = B'),
#  Text(1046.25, 611.55, 'texture_worst <= 28.545\ngini = 0.463\nsamples = 22\nvalue = [14, 8]\nclass = B'),
#  Text(941.625, 475.65, 'radius_worst <= 16.32\ngini = 0.219\nsamples = 16\nvalue = [14, 2]\nclass = B'),
#  Text(837.0, 339.75, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]\nclass = B'),
#  Text(1046.25, 339.75, 'area_worst <= 840.15\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = B'),
#  Text(941.625, 203.85000000000002, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = M'),
#  Text(1150.875, 203.85000000000002, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = B'),
#  Text(1150.875, 475.65, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = M'),
#  Text(889.3125, 747.45, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]\nclass = M'),
#  Text(1464.75, 883.35, 'concavity_mean <= 0.062\ngini = 0.06\nsamples = 130\nvalue = [4, 126]\nclass = M'),
#  Text(1360.125, 747.45, 'compactness_mean <= 0.072\ngini = 0.463\nsamples = 11\nvalue = [4, 7]\nclass = M'),
#  Text(1255.5, 611.55, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = M'),
#  Text(1464.75, 611.55, 'concave points_se <= 0.007\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = B'),
#  Text(1360.125, 475.65, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = M'),
#  Text(1569.375, 475.65, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = B'),
#  Text(1569.375, 747.45, 'gini = 0.0\nsamples = 119\nvalue = [0, 119]\nclass = M')]

# %% [markdown]
# ### Evaluating the model

# %%
# Predicting for test dataset
predictions = model.predict(X_test)

# %%
cm = confusion_matrix(Y_test, predictions, labels=model.classes_)

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)

# %%
disp.plot()

# %%
# Plotting confusion matrix
# NO ME FUNCIONÓ
ConfusionMatrixDisplay.from_predictions(Y_test, predictions)

# %%
# Calculating confusion matrix derived metrics
print('Precision:', precision_score(Y_test, predictions))
print('Recall:', recall_score(Y_test, predictions))
print('F1:', f1_score(Y_test, predictions))
# Out:
# Precision: 0.855072463768116
# Recall: 0.921875
# F1: 0.887218045112782
